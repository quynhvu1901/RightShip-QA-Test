# %% [markdown]
# Regression Testing

# %%
# %sql
-- REGRESSION TEST: vessel count consistency
SELECT COUNT(*) AS vessel_count
FROM cleaned_vessels;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vessel_count</th></tr></thead><tbody><tr><td>9</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(DISTINCT imo) AS voyage_imo_count
FROM rightship_test.default.qa_tht_sample_data_model_daily_voyage;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>voyage_imo_count</th></tr></thead><tbody><tr><td>5</td></tr></tbody></table></div>
