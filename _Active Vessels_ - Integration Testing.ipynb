# %% [markdown]
# Integration testing

# %%
# %sql
-- Join with voyage data to validate relationships then count voyage by imo
CREATE OR REPLACE TABLE vessels_data_integration_test AS
SELECT
  v.imo,
  COUNT(dv.imo) AS voyage_count
FROM cleaned_vessels AS v
LEFT JOIN rightship_test.default.qa_tht_sample_data_model_daily_voyage AS dv
  ON v.imo = dv.imo
GROUP BY v.imo;

SELECT * FROM vessels_data_integration_test;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>imo</th><th>voyage_count</th></tr></thead><tbody><tr><td>4312947302</td><td>0</td></tr><tr><td>7645524261</td><td>0</td></tr><tr><td>2950038197</td><td>0</td></tr><tr><td>2438466352</td><td>0</td></tr><tr><td>6847158436</td><td>0</td></tr><tr><td>2358534653</td><td>0</td></tr><tr><td>4807079427</td><td>15</td></tr><tr><td>5779842756</td><td>3</td></tr><tr><td>8336538328</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
-- imo is available on daily voyages but not on vessels
SELECT DISTINCT dv.imo
FROM rightship_test.default.qa_tht_sample_data_model_daily_voyage AS dv
LEFT JOIN cleaned_vessels AS v
  ON dv.imo = v.imo
WHERE v.imo IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>imo</th></tr></thead><tbody><tr><td>1000069</td></tr><tr><td>1000239</td></tr><tr><td>1000253</td></tr></tbody></table></div>
